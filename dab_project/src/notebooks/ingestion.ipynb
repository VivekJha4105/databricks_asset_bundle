# %%
dbutils.widgets.text("catalog", "")

# %%
catalog = dbutils.widgets.get("catalog")

# %%
print("catalog received ", catalog)

# %%
# %sql
SELECT * FROM IDENTIFIER(:catalog || '.information_schema.columns')
